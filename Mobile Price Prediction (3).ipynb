# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %% [markdown]
# # importing datasets

# %%
df =pd.read_excel("mobile_price_prediction.xlsx")

# %%
df
# Out:
#     Ram  f_camera  storage  battery  sim    price
# 0   NaN       NaN      NaN      NaN  NaN      NaN
# 1   6.0       8.0    128.0   6000.0  4.0  13999.0
# 2   6.0       8.0    128.0   6000.0  5.0  17999.0
# 3   2.0       5.0     32.0   5000.0  4.0   6999.0
# 4   4.0       8.0     64.0   4230.0  4.0  11149.0
# 5   6.0       8.0    128.0   4320.0  4.0  11990.0
# 6   4.0       8.0     64.0   6000.0  4.0  11499.0
# 7   4.0       8.0     64.0   5000.0  4.0   8999.0
# 8   6.0      16.0    128.0   5000.0  5.0  15999.0
# 9   2.0       8.0     32.0   3500.0  4.0   4565.0
# 10  6.0       8.0    128.0   5000.0  5.0  14990.0
# 11  8.0      32.0    128.0   4500.0  5.0  39990.0
# 12  8.0      10.0    128.0   3400.0  4.0  46500.0
# 13  4.0       8.0    128.0   6000.0  4.0  12499.0
# 14  4.0       5.0     64.0   5000.0  5.0   8999.0
# 15  6.0       8.0    128.0   5000.0  5.0  14990.0
# 16  6.0       8.0    128.0   6000.0  4.0  13499.0
# 17  6.0      20.0    128.0   6000.0  4.0  16999.0
# ...

# %% [markdown]
# # Checking For null values

# %%
df.isnull().sum()
# Out:
# Ram         1
# f_camera    1
# storage     1
# battery     1
# sim         1
# price       1
# dtype: int64

# %% [markdown]
# # Removing null values

# %%
df.dropna(inplace = True)

# %%
df
# Out:
#     Ram  f_camera  storage  battery  sim    price
# 1   6.0       8.0    128.0   6000.0  4.0  13999.0
# 2   6.0       8.0    128.0   6000.0  5.0  17999.0
# 3   2.0       5.0     32.0   5000.0  4.0   6999.0
# 4   4.0       8.0     64.0   4230.0  4.0  11149.0
# 5   6.0       8.0    128.0   4320.0  4.0  11990.0
# 6   4.0       8.0     64.0   6000.0  4.0  11499.0
# 7   4.0       8.0     64.0   5000.0  4.0   8999.0
# 8   6.0      16.0    128.0   5000.0  5.0  15999.0
# 9   2.0       8.0     32.0   3500.0  4.0   4565.0
# 10  6.0       8.0    128.0   5000.0  5.0  14990.0
# 11  8.0      32.0    128.0   4500.0  5.0  39990.0
# 12  8.0      10.0    128.0   3400.0  4.0  46500.0
# 13  4.0       8.0    128.0   6000.0  4.0  12499.0
# 14  4.0       5.0     64.0   5000.0  5.0   8999.0
# 15  6.0       8.0    128.0   5000.0  5.0  14990.0
# 16  6.0       8.0    128.0   6000.0  4.0  13499.0
# 17  6.0      20.0    128.0   6000.0  4.0  16999.0
# 18  4.0       8.0     64.0   6000.0  4.0  11499.0
# ...

# %%
x = df[["Ram","f_camera" ,"storage","battery","sim"]]
y = df["price"]

# %%
x
# Out:
#     Ram  f_camera  storage  battery  sim
# 1   6.0       8.0    128.0   6000.0  4.0
# 2   6.0       8.0    128.0   6000.0  5.0
# 3   2.0       5.0     32.0   5000.0  4.0
# 4   4.0       8.0     64.0   4230.0  4.0
# 5   6.0       8.0    128.0   4320.0  4.0
# 6   4.0       8.0     64.0   6000.0  4.0
# 7   4.0       8.0     64.0   5000.0  4.0
# 8   6.0      16.0    128.0   5000.0  5.0
# 9   2.0       8.0     32.0   3500.0  4.0
# 10  6.0       8.0    128.0   5000.0  5.0
# 11  8.0      32.0    128.0   4500.0  5.0
# 12  8.0      10.0    128.0   3400.0  4.0
# 13  4.0       8.0    128.0   6000.0  4.0
# 14  4.0       5.0     64.0   5000.0  5.0
# 15  6.0       8.0    128.0   5000.0  5.0
# 16  6.0       8.0    128.0   6000.0  4.0
# 17  6.0      20.0    128.0   6000.0  4.0
# 18  4.0       8.0     64.0   6000.0  4.0
# 19  4.0       5.0     64.0   5000.0  4.0
# 20  2.0       5.0     32.0   5000.0  4.0
# 21  6.0      16.0    128.0   5000.0  5.0
# 22  4.0       8.0     64.0   6000.0  4.0
# ...

# %%
y
# Out:
# 1     13999.0
# 2     17999.0
# 3      6999.0
# 4     11149.0
# 5     11990.0
# 6     11499.0
# 7      8999.0
# 8     15999.0
# 9      4565.0
# 10    14990.0
# 11    39990.0
# 12    46500.0
# 13    12499.0
# 14     8999.0
# 15    14990.0
# 16    13499.0
# 17    16999.0
# 18    11499.0
# 19     9499.0
# 20     6999.0
# 21    15999.0
# 22    11999.0
# 23    17999.0
# 24     7799.0
# 25     8999.0
# 26     4609.0
# 27     9990.0
# 28    15999.0
# Name: price, dtype: float64

# %% [markdown]
# # Data Visulization

# %%
plt.scatter(x.storage,y , color="blue")
plt.xlabel("storge")
plt.ylabel("price")
plt.title("mobile price prediction")
# Out:
# Text(0.5, 1.0, 'mobile price prediction')

# %%
plt.scatter(x.Ram,y , color="red")
plt.xlabel("Ram")
plt.ylabel("price")
plt.title("mobile price prediction")
# Out:
# Text(0.5, 1.0, 'mobile price prediction')

# %%
plt.bar(x.f_camera,y , color="yellow")
plt.xlabel("f_camera")
plt.ylabel("price")
plt.title("mobile price prediction")
# Out:
# Text(0.5, 1.0, 'mobile price prediction')

# %%
plt.scatter(x.sim,y, color = "brown")
plt.xlabel("sim")
plt.ylabel("price")
plt.title("mobile price prediction")
# Out:
# Text(0.5, 1.0, 'mobile price prediction')

# %%
plt.scatter(x.battery,y , color="purple")
plt.xlabel("battery")
plt.ylabel("price")
plt.title("mobile price prediction")
# Out:
# Text(0.5, 1.0, 'mobile price prediction')

# %%
from sklearn.linear_model import LinearRegression

# %%
model =LinearRegression()

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
model.predict([[6.0,8.0,64.0,5000.0,4]])
# Out:
# array([26082.46130321])

# %%
model.predict([[4.0,5.0,128.0,5000.0,4.0]])
# Out:
# array([3679.49049569])

# %%
model.coef_
# Out:
# array([ 6.82253490e+03,  2.72867308e+02, -1.24051548e+02, -1.56035349e+00,
#        -1.73439463e+03])

# %%
model.intercept_
# Out:
# 5642.958470408654

# %%
x
# Out:
#     Ram  f_camera  storage  battery  sim
# 1   6.0       8.0    128.0   6000.0  4.0
# 2   6.0       8.0    128.0   6000.0  5.0
# 3   2.0       5.0     32.0   5000.0  4.0
# 4   4.0       8.0     64.0   4230.0  4.0
# 5   6.0       8.0    128.0   4320.0  4.0
# 6   4.0       8.0     64.0   6000.0  4.0
# 7   4.0       8.0     64.0   5000.0  4.0
# 8   6.0      16.0    128.0   5000.0  5.0
# 9   2.0       8.0     32.0   3500.0  4.0
# 10  6.0       8.0    128.0   5000.0  5.0
# 11  8.0      32.0    128.0   4500.0  5.0
# 12  8.0      10.0    128.0   3400.0  4.0
# 13  4.0       8.0    128.0   6000.0  4.0
# 14  4.0       5.0     64.0   5000.0  5.0
# 15  6.0       8.0    128.0   5000.0  5.0
# 16  6.0       8.0    128.0   6000.0  4.0
# 17  6.0      20.0    128.0   6000.0  4.0
# 18  4.0       8.0     64.0   6000.0  4.0
# 19  4.0       5.0     64.0   5000.0  4.0
# 20  2.0       5.0     32.0   5000.0  4.0
# 21  6.0      16.0    128.0   5000.0  5.0
# 22  4.0       8.0     64.0   6000.0  4.0
# ...

# %%
from sklearn.model_selection import train_test_split
train_x,test_x,train_y,test_y=train_test_split(x,y,test_size=0.2)
print(len(train_x),len(test_x))
# Out:
# 22 6

# %%
model.fit(train_x,train_y)
# Out:
# LinearRegression()

# %%
df
# Out:
#     Ram  f_camera  storage  battery  sim    price
# 1   6.0       8.0    128.0   6000.0  4.0  13999.0
# 2   6.0       8.0    128.0   6000.0  5.0  17999.0
# 3   2.0       5.0     32.0   5000.0  4.0   6999.0
# 4   4.0       8.0     64.0   4230.0  4.0  11149.0
# 5   6.0       8.0    128.0   4320.0  4.0  11990.0
# 6   4.0       8.0     64.0   6000.0  4.0  11499.0
# 7   4.0       8.0     64.0   5000.0  4.0   8999.0
# 8   6.0      16.0    128.0   5000.0  5.0  15999.0
# 9   2.0       8.0     32.0   3500.0  4.0   4565.0
# 10  6.0       8.0    128.0   5000.0  5.0  14990.0
# 11  8.0      32.0    128.0   4500.0  5.0  39990.0
# 12  8.0      10.0    128.0   3400.0  4.0  46500.0
# 13  4.0       8.0    128.0   6000.0  4.0  12499.0
# 14  4.0       5.0     64.0   5000.0  5.0   8999.0
# 15  6.0       8.0    128.0   5000.0  5.0  14990.0
# 16  6.0       8.0    128.0   6000.0  4.0  13499.0
# 17  6.0      20.0    128.0   6000.0  4.0  16999.0
# 18  4.0       8.0     64.0   6000.0  4.0  11499.0
# ...

# %%
train_x
# Out:
#     Ram  f_camera  storage  battery  sim
# 1   6.0       8.0    128.0   6000.0  4.0
# 24  3.0       5.0     32.0   5000.0  4.0
# 28  6.0       8.0    128.0   5000.0  4.0
# 10  6.0       8.0    128.0   5000.0  5.0
# 21  6.0      16.0    128.0   5000.0  5.0
# 27  4.0       8.0     64.0   4320.0  4.0
# 8   6.0      16.0    128.0   5000.0  5.0
# 2   6.0       8.0    128.0   6000.0  5.0
# 5   6.0       8.0    128.0   4320.0  4.0
# 13  4.0       8.0    128.0   6000.0  4.0
# 4   4.0       8.0     64.0   4230.0  4.0
# 12  8.0      10.0    128.0   3400.0  4.0
# 9   2.0       8.0     32.0   3500.0  4.0
# 7   4.0       8.0     64.0   5000.0  4.0
# 15  6.0       8.0    128.0   5000.0  5.0
# 16  6.0       8.0    128.0   6000.0  4.0
# 6   4.0       8.0     64.0   6000.0  4.0
# 22  4.0       8.0     64.0   6000.0  4.0
# 14  4.0       5.0     64.0   5000.0  5.0
# 17  6.0      20.0    128.0   6000.0  4.0
# 20  2.0       5.0     32.0   5000.0  4.0
# 26  2.0       5.0     32.0   3200.0  4.0

# %%
train_y
# Out:
# 1     13999.0
# 24     7799.0
# 28    15999.0
# 10    14990.0
# 21    15999.0
# 27     9990.0
# 8     15999.0
# 2     17999.0
# 5     11990.0
# 13    12499.0
# 4     11149.0
# 12    46500.0
# 9      4565.0
# 7      8999.0
# 15    14990.0
# 16    13499.0
# 6     11499.0
# 22    11999.0
# 14     8999.0
# 17    16999.0
# 20     6999.0
# 26     4609.0
# Name: price, dtype: float64

# %%
test_x,test_y
# Out:
# (    Ram  f_camera  storage  battery  sim
#  25  4.0       5.0     64.0   5000.0  4.0
#  18  4.0       8.0     64.0   6000.0  4.0
#  23  6.0       8.0    128.0   6000.0  5.0
#  19  4.0       5.0     64.0   5000.0  4.0
#  3   2.0       5.0     32.0   5000.0  4.0
#  11  8.0      32.0    128.0   4500.0  5.0,
#  25     8999.0
#  18    11499.0
#  23    17999.0
#  19     9499.0
#  3      6999.0
#  11    39990.0
#  Name: price, dtype: float64)

# %%
model.predict(test_x)
# Out:
# array([12011.0637708 , 10328.89044405, 14470.55654573, 12011.0637708 ,
#         1836.21846882, 31095.86349518])

# %%
test_y
# Out:
# 25     8999.0
# 18    11499.0
# 23    17999.0
# 19     9499.0
# 3      6999.0
# 11    39990.0
# Name: price, dtype: float64

# %%
model.score(test_x,test_y)
# Out:
# 0.8251556949849009

# %%
model.predict([[6,8,128,5000,4]])
# Out:
# array([15750.78762596])

# %%
pred_y = model.predict(x)

# %%
pred_y
# Out:
# array([13892.8243759 , 13438.07091468,   921.5620932 , 14515.33975709,
#        17014.202636  , 11226.74480449, 13084.70805454, 16284.06247236,
#         4079.01758365, 15296.03416474, 40108.29183318, 39889.72702351,
#        -7026.36674464, 12259.44397796, 15296.03416474, 13892.8243759 ,
#        15374.86683734, 11226.74480449, 12714.19743919,   921.5620932 ,
#        16284.06247236, 11226.74480449, 13438.07091468, 11381.15765348,
#        12714.19743919,  4265.89594331, 14348.12306458, 15750.78762596])

# %%
model.predict([[8,15,128,5000,4]])
# Out:
# array([37534.50351568])
